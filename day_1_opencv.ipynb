# %%
#version open cv 
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
print(cv2.__version__)
# Out:
# 4.10.0

# %%
# loader les images 
image = cv2.imread('Photos/apple.jpeg')
# image

# %%
# function for displaying an image
def imshow(title="", image=None):
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

imshow(title="Display an apple image", image=image)

# %%
# saving an image after a processing 
cv2.imwrite('output.jpg',image)
# Out:
# True

# %%
# printing the shape of an image 
print(image.shape)
# Out:
# (4032, 3024, 3)

# %% [markdown]
# #### transform the color of an image

# %%
def imshow(title="", image=None,size=10):
    w,h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size*aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
image = cv2.imread("Photos/papaya.jpeg")
imshow("Fruit",image=image)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
imshow("converted to Grayscale",gray_image)

# %%
# shape of our gray_image 
gray_image.shape
# Out:
# (4819, 3213)

# %% [markdown]
# Extracting color from image

# %%
image = cv2.imread("Photos/pineapple.jpeg")

# Use cv2 to split the color dimension 
B,G,R = cv2.split(image)
print(B.shape, G.shape, R.shape)
# Out:
# (3072, 2048) (3072, 2048) (3072, 2048)

# %%
#show decomposed Green image
imshow(image=B)

# %% [markdown]
# Rebuilding an split image

# %%
zeros = np.zeros(image.shape[:2],dtype='uint8')

imshow(title="Red", image=cv2.merge([zeros,zeros,R]))
imshow(title="Green", image=cv2.merge([zeros,G,zeros]))
imshow(title="Blue", image=cv2.merge([B,zeros,R]))

# %%
#Reconstruction de l'image 
merged =cv2.merge([B,G,R])
imshow("Merged", image=merged)

# %%
imshow("add blue color to an image", image=cv2.merge([B+100,G,R]))

# %% [markdown]
# Using the HSV color

# %%
image = cv2.imread('Photos/apple.jpeg')
# Convertir en HSV
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
imshow('HSV', hsv_image)

# %%
imshow(title="Hue", image=hsv_image[:,:,0])
imshow(title="Saturation", image=hsv_image[:,:,1])
imshow(title="Value", image=hsv_image[:,:,2])
